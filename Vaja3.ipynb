# %%
from qiskit import QuantumCircuit
from qiskit.primitives import StatevectorSampler
from math import pi
qc = QuantumCircuit(10)

qc.rx(pi/2,range(10))
qc.rx(pi/3,0)
qc.rx(pi/3,3)
qc.rx(pi/3,9)
qc.rx(-pi/3,1)
qc.rx(-pi/3,2)
qc.rx(-pi/3,4)
qc.rx(-pi/3,5)
qc.rx(-pi/3,6)
qc.rx(-pi/3,7)
qc.rx(-pi/3,8)




qc.measure_all()

sampler = StatevectorSampler()
result = sampler.run([qc], shots=10000).result()
#result = sampler.run([qc], shots=10).result()
print(result[0].data.meas.get_counts())
# Out:
# {'1000001001': 100}

# %%
from qiskit import QuantumCircuit
from qiskit.primitives import StatevectorSampler
from math import pi
qc = QuantumCircuit(10)

qc.rx(pi/2,range(10))
qc.rx(pi/3,0)
qc.rx(pi/3,3)
qc.rx(pi/3,9)
qc.rx(-pi/3,1)
qc.rx(-pi/3,2)
qc.rx(-pi/3,4)
qc.rx(-pi/3,5)
qc.rx(-pi/3,6)
qc.rx(-pi/3,7)
qc.rx(-pi/3,8)




qc.measure_all()

sampler = StatevectorSampler()
result = sampler.run([qc], shots=10000).result()
#result = sampler.run([qc], shots=10).result()
print(result[0].data.meas.get_counts())

# %%
from qiskit.visualization import plot_histogram

counts = result[0].data.meas.get_counts()
decimal_counts = dict(
    sorted(
        ((str(int(k, 2)), v) for k, v in counts.items()),
        key=lambda item: int(item[0])
    )
)
plot_histogram(decimal_counts)

# %% [markdown]
# Kaj ste morali spremeniti v algoritmu, da ste dosegli željeno generiranje naključnih števil?

# %% [markdown]
# - spremeniti količino qbitov iz 12 na 10

# %% [markdown]
# Ali bi lahko zgoraj navedeno, dosegli s pomočjo Hadamardovih vrat? Odgovor utemeljite.
